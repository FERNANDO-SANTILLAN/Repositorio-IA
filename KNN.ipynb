# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, classification_report

# %%
# Cargar el conjunto de datos Iris
iris = load_iris()
X = iris.data
y = iris.target
print("Nombres de las clases:", iris.target_names)
print("Características:", iris.feature_names)
# Out:
# Nombres de las clases: ['setosa' 'versicolor' 'virginica']
# Características: ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']

# %%
# Dos características para graficar (por ejemplo, largo y ancho del pétalo)
plt.figure(figsize=(8,6))
for i in range(3):
    plt.scatter(X[y == i, 2], X[y == i, 3], label=iris.target_names[i])
plt.xlabel("Largo del pétalo (cm)")
plt.ylabel("Ancho del pétalo (cm)")
plt.title("Visualización de clases Iris 🌸")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 127800 (\N{CHERRY BLOSSOM}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
X_entrenamiento, X_prueba, y_entrenamiento, y_prueba = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# Modelo KNN con k=3
modelo_knn = KNeighborsClassifier(n_neighbors=3)
modelo_knn.fit(X_entrenamiento, y_entrenamiento)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
# Predecir sobre los datos de prueba
y_pred = modelo_knn.predict(X_prueba)
print("Exactitud:", accuracy_score(y_prueba, y_pred))
print("\nReporte de clasificación:\n", classification_report(y_prueba, y_pred, target_names=iris.target_names))
# Out:
# Exactitud: 1.0
#
# Reporte de clasificación:
#                precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        19
#   versicolor       1.00      1.00      1.00        13
#    virginica       1.00      1.00      1.00        13
#
#     accuracy                           1.00        45
#    macro avg       1.00      1.00      1.00        45
# weighted avg       1.00      1.00      1.00        45

# %%
# Visualización de los datos de prueba con sus predicciones
plt.figure(figsize=(8,6))
for i in range(3):
    plt.scatter(X_prueba[y_pred == i, 2], X_prueba[y_pred == i, 3], label=f"Predicho: {iris.target_names[i]}")
plt.xlabel("Largo del pétalo (cm)")
plt.ylabel("Ancho del pétalo (cm)")
plt.title("Predicciones del modelo KNN")
plt.legend()
plt.grid(True)
plt.show()
